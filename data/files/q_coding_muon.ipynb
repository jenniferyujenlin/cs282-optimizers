# %%
# Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Problem Intro
#
# In this problem, we will implement key components of the Muon optimizer in PyTorch. Then,  we will compare Muon against SGD and AdamW empirically to demonstrate the benefits of Muon.
#
# We will train a sample CNN architecture on CIFAR10 image data (initialized below).

# %%
# Define a sample CNN for CIFAR-10
class CIFAR10CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 10)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# Dataset & loader with augmentation
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Increase batch size for more realistic training
batch_size = 128

train_ds = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform_train)
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)

test_ds = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform_test)
test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 170M/170M [00:10<00:00, 16.1MB/s]

# %% [markdown]
# ## Part 1: Implementing Newton-Schulz
#
# The core of Muon is using matrix orthogonalization on a typical gradient update matrix. After orthogonalization:
# * Singular values become more uniform
# * Updates act across all directions in parameter space
# * The neural network can utilize its full parameter capacity (because parameters are all receiving nontrivial gradients)
#
# In Muon, matrix orthogonalization is done using Newton-Schulz. Newton-Schulz relies on iteration using an odd matrix polynomial. In this problem, we consider a very simple cubic polynomial, but many odd polynomials can be used (state-of-the-art implementations use specific, tuned quintic polynomial).
#
# **Complete the following code** to implement Newton-Schulz, using the matrix polynomial in the comments.

# %%
def newton_schulz_orthogonalize(X: torch.Tensor, num_iters: int):
    """
    Apply Newton-Schulz iterations to approximate orthogonalization.

    This function applies the polynomial f(X) = (3X - X^3)/2 repeatedly to a normalized matrix,
    which gradually forces all singular values to 1 while preserving singular vectors.

    Args:
      X (torch.Tensor): Input matrix to orthogonalize
      num_iters (int): Number of Newton-Schulz iterations

    Returns:
      torch.Tensor: Orthogonalized matrix
    """
    dtype = X.dtype
    # Use bfloat16 for potential speed/memory savings during the iterations
    X = X.bfloat16()
    # Recall from prior homeworks that we can transpose the matrix to speed up computation.
    transposed = False
    if X.size(-2) < X.size(-1):
        transposed = True
        X = X.mT

    # Ensure spectral norm is at most sqrt(3)
    norm = torch.linalg.norm(X, dim=(-2, -1), keepdim=True)
    X = torch.div(X, norm + 1e-7) * (3**0.5)

    ################################################################################
    # TODO: YOUR CODE HERE
    ################################################################################
    ################################################################################

    if transposed:
        X = X.mT

    return X.to(dtype)

# %% [markdown]
# ### Question 1
#
# Notice that in the above implementation, we scale the spectral norm to be at most sqrt(3). **Can you explain why we choose this particular scaling?**
#
# *(Hint: Inspect the roots of the cubic polynomial. What is the connection between the roots and the convergence properties of the singular values? You can refer to Discussion 4 for the answer)*

# %% [markdown]
# ## Part 2: Implementing Muon Update
#
# Now, we implement the update in a Muon optimizer. Given parameter matrix $W$ with momentum matrix $M$, the pseudocode for the Muon update proceeds as follows:
#
# ```
# d_out, d_in = M.shape
#
# # Apply Newton-Schulz orthogonalization
# M ← newton_schulz_orthogonalize(M, ns_iters)
#
# # Apply muP scaling factor for consistent update magnitude
# M ← M · sqrt(max(1, d_out / d_in))
# ```
#
# Then, the Muon update is used later to update the parameters W:
# ```
# # Update the parameter matrix
# W  ← W - lr * M
# ```
#
# **Complete the following code** to implement the Muon update following the above pseudocode.

# %%
import torch.optim as optim

def muon_update(grad, momentum, beta=0.95, ns_iters=5):
    momentum.lerp_(grad, 1 - beta)  # momentum = beta * momentum + (1-beta) * grad
    update = momentum.clone()

    # If the parameter is a convolutional kernel, then flatten to a 2D matrix
    original_shape = update.shape
    reshaped = False
    if update.ndim > 2:
        reshaped = True
        update = update.view(update.size(0), -1)

    ################################################################################
    # TODO: YOUR CODE HERE
    ################################################################################
    ################################################################################

    # Restore shape if needed
    if reshaped:
        update = update.view(original_shape)

    return update


class Muon(optim.Optimizer):
    def __init__(self, params, lr=0.01, beta=0.95, ns_iters=5,
                weight_decay=0):

        defaults = dict(lr=lr, beta=beta, ns_iters=ns_iters,
                        weight_decay=weight_decay)
        super().__init__(params, defaults)

    @torch.no_grad()
    def step(self, closure=None):
        for group in self.param_groups:
            lr = group['lr']
            beta = group['beta']
            ns_iters = group['ns_iters']
            weight_decay = group['weight_decay']

            for p in group['params']:
                if p.grad is None:
                    continue

                grad = p.grad
                # Get state for this parameter
                state = self.state[p]
                # Initialize momentum buffer if it doesn't exist
                if 'momentum' not in state:
                    state['momentum'] = torch.zeros_like(grad)

                # Apply weight decay directly to parameters (AdamW style)
                if weight_decay != 0:
                    p.mul_(1 - lr * weight_decay)

                # Apply newton_schulz if parameter is a matrix
                if p.ndim >= 2:
                    update = muon_update(grad, state['momentum'],
                                         beta=beta, ns_iters=ns_iters)
                    # Apply update to parameters
                    p.add_(update, alpha=-lr)
                else:
                    # For non-matrix parameters, i.e. bias, use standard momentum update
                    momentum = state['momentum']
                    momentum.mul_(beta).add_(grad)
                    p.add_(momentum, alpha=-lr)

        return None

# %% [markdown]
# ### Question 2
#
# Note that Muon requires that parameters are 2D matrices of shape $d_{out} \times d_{in}$. However, we know that parameters that are convolutional kernels have shape $c_{out} \times c_{in} \times k \times k$ where $c$ denotes number of channels and $k$ is kernel size.
#
# Modern implementations of convolutional layers will transform an input image $\mathbf{x}$ of shape $c_{in} \times h \times w$ to $\mathbf{x}'$ such that each column has size $c_{in} \cdot k \cdot k$ and corresponds to one flattened "receptive field" of the image (or one patch of the image that a convolutional filter passes over to compute one pixel in the output).
#
# Given this fact, **how do we modify the convolutional kernel into a $d_{out} \times d_{in}$ matrix $C$ such that the output of the convolutional layer can be expressed as $C \mathbf{x}'$**.

# %% [markdown]
# ## Part 3: Empirical Evaluation of Muon
#
# Now, we'll train the CNN network on the CIFAR10 dataset using our Muon implementation, comparing performance on the test set against other popular optimizers in SGD and AdamW.
#
# First, in addition to SGD and AdamW, we consider two additional baseline optimizers that will help us better interpret our results:
#
#
# *   MuonSVD: Rather than using Newton-Schulz, we orthogonalize the momentum using SVD on the momentum matrix $M = U\Sigma V^T$ and computing $UV^T$.
# *   AdamWMuP: We add the muP scaling on top of the AdamW optimizer. This is meant the help us better understand how much of the Muon performance is due to the orthogonalization step, and how much is simply from the muP scaling.
#
# The cell below implements these two additional optimizers. You do not have to implement anything.

# %%
import torch.optim as optim

def muon_update_svd(grad, momentum, beta=0.95):
    momentum.lerp_(grad, 1 - beta)  # momentum = beta * momentum + (1-beta) * grad
    update = momentum.clone()

    # If the parameter is a convolutional kernel, then flatten to a 2D matrix
    original_shape = update.shape
    reshaped = False
    if update.ndim > 2:
        reshaped = True
        update = update.view(update.size(0), -1)

    # Orthogonalization via SVD - specify full_matrices=False for reduced SVD
    U, _, Vh = torch.linalg.svd(update, full_matrices=False)
    update = torch.matmul(U, Vh)

    # Apply muP scaling
    update.mul_(max(1, update.size(-2) / update.size(-1))**0.5)

    # Restore shape if needed
    if reshaped:
        update = update.view(original_shape)

    return update


class MuonSVD(optim.Optimizer):
    def __init__(self, params, lr=0.01, beta=0.95, weight_decay=0):

        defaults = dict(lr=lr, beta=beta, weight_decay=weight_decay)
        super().__init__(params, defaults)

    @torch.no_grad()
    def step(self, closure=None):
        for group in self.param_groups:
            lr = group['lr']
            beta = group['beta']
            weight_decay = group['weight_decay']

            for p in group['params']:
                if p.grad is None:
                    continue

                grad = p.grad
                # Get state for this parameter
                state = self.state[p]
                # Initialize momentum buffer if it doesn't exist
                if 'momentum' not in state:
                    state['momentum'] = torch.zeros_like(grad)

                # Apply weight decay directly to parameters (AdamW style)
                if weight_decay != 0:
                    p.mul_(1 - lr * weight_decay)

                # Apply newton_schulz if parameter is a matrix
                if p.ndim >= 2:
                    update = muon_update_svd(grad, state['momentum'], beta=beta)
                    # Apply update to parameters
                    p.add_(update, alpha=-lr)
                else:
                    # For non-matrix parameters, i.e. bias, use standard momentum update
                    momentum = state['momentum']
                    momentum.mul_(beta).add_(grad)
                    p.add_(momentum, alpha=-lr)

        return None


class AdamWMuP(optim.Optimizer):
    def __init__(self,  params, lr=0.01, betas=(0.9, 0.999), weight_decay=0):
        defaults = dict(lr=lr, betas=betas, weight_decay=weight_decay)
        super().__init__(params, defaults)

    @torch.no_grad()
    def step(self):
        for group in self.param_groups:
            lr = group['lr']
            weight_decay = group['weight_decay']

            for p in group['params']:
                grad = p.grad.data

                state = self.state[p]
                if len(state) == 0: # Initialization
                    state["step"] = torch.tensor(0.0)
                    state['momentum'] = torch.zeros_like(p)
                    state['variance'] = torch.zeros_like(p)

                if weight_decay != 0:
                    p.mul_(1 - lr * weight_decay)

                state['step'] += 1
                m = state['momentum']
                m.lerp_(grad, 1 - group["betas"][0])
                v = state['variance']
                v.lerp_(grad**2, 1 - group["betas"][1])

                m_hat = m / (1 - group["betas"][0]**state['step'])
                v_hat = v / (1 - group["betas"][1]**state['step'])
                u = m_hat / (torch.sqrt(v_hat) + 1e-16)

                if p.ndim >= 2:
                    # If the parameter is a convolutional kernel, then flatten to a 2D matrix
                    original_shape = u.shape
                    reshaped = False
                    if u.ndim > 2:
                        u = u.view(u.shape[0], -1)  # keep first dim, flatten the rest
                        reshaped = True

                    u.mul_(max(1, u.size(-2) / u.size(-1))**0.5)

                    # Unflatten back to convolutional kernel
                    if reshaped:
                        u = u.view(original_shape)

                p.add_(u, alpha=-lr)

        return None

# %% [markdown]
# If you performed hyperparameter sweeping (optional part below), then replace the default hyperparameters with the values you found from your sweep. Then, run the following cell to investigate how good Muon is relative to other baseline optimizers. The cell should take less than 10 minutes if you use a GPU runtime on Colab.

# %%
import torch
from torch.optim import Optimizer

class SOAP(Optimizer):
    def __init__(self, params, lr=1e-3, beta=0.9, eps=1e-8):
        defaults = dict(lr=lr, beta=beta, eps=eps)
        super().__init__(params, defaults)

    @torch.no_grad()
    def step(self):
        for group in self.param_groups:
            lr = group['lr']
            beta = group['beta']
            eps = group['eps']

            for p in group['params']:
                if p.grad is None:
                    continue

                grad = p.grad

                # Create momentum buffer if missing
                state = self.state[p]
                if 'avg' not in state:
                    state['avg'] = torch.zeros_like(p)

                avg = state['avg']

                # Prox-like averaged update
                avg.mul_(beta).add_(grad, alpha=1 - beta)

                # Second-order approximation step
                update = avg / (avg.norm() + eps)

                p.add_(update, alpha=-lr)

class Lion(Optimizer):
    def __init__(self, params, lr=1e-4, betas=(0.9, 0.99), weight_decay=0.0):
        defaults = dict(lr=lr, betas=betas, weight_decay=weight_decay)
        super().__init__(params, defaults)

    @torch.no_grad()
    def step(self, closure=None):
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            lr = group["lr"]
            beta1, beta2 = group["betas"]
            wd = group["weight_decay"]

            for p in group["params"]:
                if p.grad is None:
                    continue

                g = p.grad
                if wd != 0:
                    g = g.add(p, alpha=wd)

                state = self.state[p]
                if "exp_avg" not in state:
                    state["exp_avg"] = torch.zeros_like(p)

                exp_avg = state["exp_avg"]
                exp_avg.mul_(beta1).add_(g, alpha=1 - beta1)

                update = exp_avg.sign()
                p.add_(update, alpha=-lr)

        return loss

# %%
# --- Define the optimizers you want to compare ---
optimizers_dict = {
    "SOAP": lambda params: SOAP(params, lr=1e-2),
    "Lion": lambda params: Lion(params, lr=1e-3),

    "Muon": lambda params: Muon(params, lr=1e-2, weight_decay=0),
    "SGD": lambda params: torch.optim.SGD(params, lr=1e-2, momentum=0.9, weight_decay=1e-4),
    "AdamW": lambda params: torch.optim.AdamW(params, lr=1e-3, weight_decay=1e-3),
    "MuonSVD": lambda params: MuonSVD(params, lr=1e-2, weight_decay=0),
    "AdamWMuP": lambda params: AdamWMuP(params, lr=1e-3, weight_decay=1e-3),
}

device = "cuda" if torch.cuda.is_available() else "cpu"
criterion = nn.CrossEntropyLoss()

# Function to evaluate model
def evaluate(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total


results = {}  # store loss curves
accuracy_results = {}  # store accuracy curves

# --- Train for each optimizer ---
for opt_name, opt_fn in optimizers_dict.items():
    print(f"\n--- Training with {opt_name} ---")
    model = CIFAR10CNN().to(device)  # re-init model each time
    optimizer = opt_fn(model.parameters())

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5)

    losses = []
    accuracies = []
    epoch_times = []

    for epoch in range(1, 6):  # Train for 5 epochs
        model.train()
        epoch_start_time = time.time()
        total_loss = 0

        for i, (x, y) in enumerate(train_loader):
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

            # Print progress
            if (i+1) % 100 == 0:
                print(f'Epoch [{epoch}/5], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

        epoch_end_time = time.time()
        epoch_duration = epoch_end_time - epoch_start_time
        epoch_times.append(epoch_duration)

        # Evaluate
        test_acc = evaluate(model, test_loader)

        avg_loss = total_loss / len(train_loader)
        losses.append(avg_loss)
        accuracies.append(test_acc)

        print(f"{opt_name} | Epoch {epoch}, avg loss: {avg_loss:.4f}, test acc: {test_acc:.2f}%, time: {epoch_duration:.2f} seconds")

        # Update learning rate
        scheduler.step()

    results[opt_name] = losses
    accuracy_results[opt_name] = accuracies

    # Calculate and print total training time
    total_time = sum(epoch_times)
    print(f"{opt_name} | Total training time: {total_time:.2f} seconds")

# --- Plot results ---
# 1. Loss vs Epoch
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
for opt_name, losses in results.items():
    plt.plot(range(1, len(losses)+1), losses, label=opt_name, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.title("Training Loss vs Epoch for Different Optimizers")
plt.legend()
plt.grid(True)

# 2. Accuracy vs Epoch
plt.subplot(1, 2, 2)
for opt_name, accuracies in accuracy_results.items():
    plt.plot(range(1, len(accuracies)+1), accuracies, label=opt_name, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Test Accuracy vs Epoch for Different Optimizers")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# --- Training with SOAP ---
# Epoch [1/5], Step [100/391], Loss: 1.9494
# Epoch [1/5], Step [200/391], Loss: 1.6839
# Epoch [1/5], Step [300/391], Loss: 1.7404
# SOAP | Epoch 1, avg loss: 1.8753, test acc: 42.99%, time: 17.18 seconds
# Epoch [2/5], Step [100/391], Loss: 1.5070
# Epoch [2/5], Step [200/391], Loss: 1.6702
# Epoch [2/5], Step [300/391], Loss: 1.4843
# SOAP | Epoch 2, avg loss: 1.5568, test acc: 50.20%, time: 17.10 seconds
# Epoch [3/5], Step [100/391], Loss: 1.4457
# Epoch [3/5], Step [200/391], Loss: 1.6067
# Epoch [3/5], Step [300/391], Loss: 1.3670
# SOAP | Epoch 3, avg loss: 1.4382, test acc: 53.87%, time: 18.03 seconds
# Epoch [4/5], Step [100/391], Loss: 1.3824
# Epoch [4/5], Step [200/391], Loss: 1.2066
# Epoch [4/5], Step [300/391], Loss: 1.3763
# SOAP | Epoch 4, avg loss: 1.3706, test acc: 56.02%, time: 17.59 seconds
# Epoch [5/5], Step [100/391], Loss: 1.3911
# Epoch [5/5], Step [200/391], Loss: 1.3623
# Epoch [5/5], Step [300/391], Loss: 1.3752
# SOAP | Epoch 5, avg loss: 1.3372, test acc: 56.54%, time: 17.87 seconds
# SOAP | Total training time: 87.77 seconds
#
# --- Training with Lion ---
# Epoch [1/5], Step [100/391], Loss: 1.7517
# Epoch [1/5], Step [200/391], Loss: 1.6951
# Epoch [1/5], Step [300/391], Loss: 1.5964
# Lion | Epoch 1, avg loss: 1.6453, test acc: 52.95%, time: 16.92 seconds
# Epoch [2/5], Step [100/391], Loss: 1.3211
# Epoch [2/5], Step [200/391], Loss: 1.3418
# Epoch [2/5], Step [300/391], Loss: 1.2217
# Lion | Epoch 2, avg loss: 1.3101, test acc: 61.59%, time: 17.60 seconds
# Epoch [3/5], Step [100/391], Loss: 1.4188
# Epoch [3/5], Step [200/391], Loss: 1.1146
# Epoch [3/5], Step [300/391], Loss: 1.0283
# Lion | Epoch 3, avg loss: 1.1559, test acc: 63.99%, time: 17.19 seconds
# Epoch [4/5], Step [100/391], Loss: 1.1509
# Epoch [4/5], Step [200/391], Loss: 1.0731
# Epoch [4/5], Step [300/391], Loss: 1.0583
# Lion | Epoch 4, avg loss: 1.0378, test acc: 67.09%, time: 17.02 seconds
# Epoch [5/5], Step [100/391], Loss: 0.9831
# Epoch [5/5], Step [200/391], Loss: 0.8608
# Epoch [5/5], Step [300/391], Loss: 0.9891
# Lion | Epoch 5, avg loss: 0.9629, test acc: 69.33%, time: 17.79 seconds
# Lion | Total training time: 86.51 seconds
#
# --- Training with Muon ---
# Epoch [1/5], Step [100/391], Loss: 2.2944
# Epoch [1/5], Step [200/391], Loss: 2.2364
# Epoch [1/5], Step [300/391], Loss: 2.1806
# Muon | Epoch 1, avg loss: 2.2228, test acc: 28.43%, time: 16.96 seconds
# Epoch [2/5], Step [100/391], Loss: 1.9623
# Epoch [2/5], Step [200/391], Loss: 1.9538
# Epoch [2/5], Step [300/391], Loss: 2.0015
# Muon | Epoch 2, avg loss: 1.9964, test acc: 33.45%, time: 18.04 seconds
# Epoch [3/5], Step [100/391], Loss: 1.9126
# Epoch [3/5], Step [200/391], Loss: 1.9071
# Epoch [3/5], Step [300/391], Loss: 1.7922
# Muon | Epoch 3, avg loss: 1.8807, test acc: 38.05%, time: 17.02 seconds
# Epoch [4/5], Step [100/391], Loss: 1.9657
# Epoch [4/5], Step [200/391], Loss: 1.7293
# Epoch [4/5], Step [300/391], Loss: 1.7892
# Muon | Epoch 4, avg loss: 1.7977, test acc: 39.52%, time: 17.94 seconds
# Epoch [5/5], Step [100/391], Loss: 1.7148
# Epoch [5/5], Step [200/391], Loss: 1.7808
# Epoch [5/5], Step [300/391], Loss: 1.7675
# Muon | Epoch 5, avg loss: 1.7603, test acc: 39.86%, time: 16.81 seconds
# Muon | Total training time: 86.78 seconds
#
# --- Training with SGD ---
# Epoch [1/5], Step [100/391], Loss: 2.0049
# Epoch [1/5], Step [200/391], Loss: 1.7838
# Epoch [1/5], Step [300/391], Loss: 1.6296
# SGD | Epoch 1, avg loss: 1.8644, test acc: 46.21%, time: 17.97 seconds
# Epoch [2/5], Step [100/391], Loss: 1.4644
# Epoch [2/5], Step [200/391], Loss: 1.5069
# Epoch [2/5], Step [300/391], Loss: 1.3888
# SGD | Epoch 2, avg loss: 1.4867, test acc: 54.53%, time: 16.80 seconds
# Epoch [3/5], Step [100/391], Loss: 1.3235
# Epoch [3/5], Step [200/391], Loss: 1.4329
# Epoch [3/5], Step [300/391], Loss: 1.3541
# SGD | Epoch 3, avg loss: 1.3155, test acc: 58.79%, time: 17.44 seconds
# Epoch [4/5], Step [100/391], Loss: 1.2126
# Epoch [4/5], Step [200/391], Loss: 1.2079
# Epoch [4/5], Step [300/391], Loss: 1.0842
# SGD | Epoch 4, avg loss: 1.1860, test acc: 62.76%, time: 16.97 seconds
# Epoch [5/5], Step [100/391], Loss: 1.0491
# Epoch [5/5], Step [200/391], Loss: 1.0413
# Epoch [5/5], Step [300/391], Loss: 1.1116
# SGD | Epoch 5, avg loss: 1.1106, test acc: 64.43%, time: 16.83 seconds
# SGD | Total training time: 86.01 seconds
#
# --- Training with AdamW ---
# Epoch [1/5], Step [100/391], Loss: 1.7582
# Epoch [1/5], Step [200/391], Loss: 1.5448
# Epoch [1/5], Step [300/391], Loss: 1.3862
# AdamW | Epoch 1, avg loss: 1.6059, test acc: 54.92%, time: 16.99 seconds
# Epoch [2/5], Step [100/391], Loss: 1.3038
# Epoch [2/5], Step [200/391], Loss: 1.0930
# Epoch [2/5], Step [300/391], Loss: 1.0549
# AdamW | Epoch 2, avg loss: 1.2433, test acc: 64.26%, time: 16.79 seconds
# Epoch [3/5], Step [100/391], Loss: 1.0363
# Epoch [3/5], Step [200/391], Loss: 0.9574
# Epoch [3/5], Step [300/391], Loss: 1.0640
# AdamW | Epoch 3, avg loss: 1.0584, test acc: 67.98%, time: 17.54 seconds
# Epoch [4/5], Step [100/391], Loss: 1.1310
# Epoch [4/5], Step [200/391], Loss: 0.8151
# Epoch [4/5], Step [300/391], Loss: 1.0203
# AdamW | Epoch 4, avg loss: 0.9456, test acc: 70.20%, time: 16.71 seconds
# Epoch [5/5], Step [100/391], Loss: 0.7970
# Epoch [5/5], Step [200/391], Loss: 0.7977
# Epoch [5/5], Step [300/391], Loss: 0.9339
# AdamW | Epoch 5, avg loss: 0.8819, test acc: 71.65%, time: 17.93 seconds
# AdamW | Total training time: 85.96 seconds
#
# --- Training with MuonSVD ---
# /tmp/ipython-input-3592678830.py:15: UserWarning: torch.linalg.svd: During SVD computation with the selected cusolver driver, batches 0 failed to converge. A more accurate method will be used to compute the SVD as a fallback. Check doc at https://pytorch.org/docs/stable/generated/torch.linalg.svd.html (Triggered internally at /pytorch/aten/src/ATen/native/cuda/linalg/BatchLinearAlgebraLib.cpp:702.)
#   U, _, Vh = torch.linalg.svd(update, full_matrices=False)
# Epoch [1/5], Step [100/391], Loss: 1.5309
# Epoch [1/5], Step [200/391], Loss: 1.3255
# Epoch [1/5], Step [300/391], Loss: 1.1789
# MuonSVD | Epoch 1, avg loss: 1.4552, test acc: 67.99%, time: 26.14 seconds
# Epoch [2/5], Step [100/391], Loss: 1.1150
# Epoch [2/5], Step [200/391], Loss: 1.0617
# Epoch [2/5], Step [300/391], Loss: 1.0015
# MuonSVD | Epoch 2, avg loss: 1.0091, test acc: 71.57%, time: 23.88 seconds
# Epoch [3/5], Step [100/391], Loss: 0.9657
# Epoch [3/5], Step [200/391], Loss: 0.7019
# Epoch [3/5], Step [300/391], Loss: 0.7510
# MuonSVD | Epoch 3, avg loss: 0.8575, test acc: 76.66%, time: 24.23 seconds
# Epoch [4/5], Step [100/391], Loss: 0.8442
# Epoch [4/5], Step [200/391], Loss: 0.7861
# Epoch [4/5], Step [300/391], Loss: 0.5476
# MuonSVD | Epoch 4, avg loss: 0.7254, test acc: 79.91%, time: 24.16 seconds
# Epoch [5/5], Step [100/391], Loss: 0.5719
# Epoch [5/5], Step [200/391], Loss: 0.6793
# Epoch [5/5], Step [300/391], Loss: 0.5430
# MuonSVD | Epoch 5, avg loss: 0.6429, test acc: 80.89%, time: 24.31 seconds
# MuonSVD | Total training time: 122.71 seconds
#
# --- Training with AdamWMuP ---
# Epoch [1/5], Step [100/391], Loss: 1.7440
# Epoch [1/5], Step [200/391], Loss: 1.4043
# Epoch [1/5], Step [300/391], Loss: 1.4703
# AdamWMuP | Epoch 1, avg loss: 1.6247, test acc: 52.77%, time: 18.10 seconds
# Epoch [2/5], Step [100/391], Loss: 1.3312
# Epoch [2/5], Step [200/391], Loss: 1.0451
# Epoch [2/5], Step [300/391], Loss: 1.0728
# AdamWMuP | Epoch 2, avg loss: 1.2116, test acc: 63.10%, time: 17.27 seconds
# Epoch [3/5], Step [100/391], Loss: 1.0028
# Epoch [3/5], Step [200/391], Loss: 0.9934
# Epoch [3/5], Step [300/391], Loss: 1.0684
# AdamWMuP | Epoch 3, avg loss: 1.0323, test acc: 69.24%, time: 17.69 seconds
# Epoch [4/5], Step [100/391], Loss: 1.0310
# Epoch [4/5], Step [200/391], Loss: 0.9127
# Epoch [4/5], Step [300/391], Loss: 0.8732
# AdamWMuP | Epoch 4, avg loss: 0.9264, test acc: 71.16%, time: 16.99 seconds
# Epoch [5/5], Step [100/391], Loss: 0.8872
# Epoch [5/5], Step [200/391], Loss: 0.9731
# Epoch [5/5], Step [300/391], Loss: 0.8503
# AdamWMuP | Epoch 5, avg loss: 0.8622, test acc: 72.41%, time: 17.14 seconds
# AdamWMuP | Total training time: 87.19 seconds

# %% [markdown]
# ### Question 3
#
# **Which optimizer performed best between Muon, SGD, and AdamW?** Also **copy the resulting plots** into the submission as well.

# %% [markdown]
# ### Question 4
#
# Compare the loss curves between Muon and MuonSVD. **Are the results expected? Explain why.**

# %% [markdown]
# ### Question 5
#
# The Muon optimizer contains two key differences: (1) orthogonalization of the momentum, and (2) muP scaling of the momentum. **Between orthogonalization and muP scaling, which seemed to matter more?** Reference the loss curves to justify your answer.

# %% [markdown]
# ### Question 6 (Optional)
#
# Our implementation of Newton-Schulz is suboptimal in the polynomial used for convergence.
# The community has developed quintic polynomials that converge faster while still being efficient. **Implement an improved Newton-Schulz and compare. Comment on the speed advantage of the improved Muon relative to the MuonSVD.**
#
# *(Hint: You can modify the number of iterations by setting the ns_iters parameter in the Muon optimizer)*

# %% [markdown]
# ## Part 4 (Optional): Hyperparameter sweeps
#
# To ensure that we are making fair comparisons, we will sweep over both learning rate and weight decay for both Muon and AdamW (the likely strongest competing optimizer). We choose these two parameters because empirically, they have the greatest effect on training.
#
# Running the sweep should take less than 1 hour total on a GPU runtime.

# %%
from torch.utils.data import random_split

device = "cuda" if torch.cuda.is_available() else "cpu"
criterion = nn.CrossEntropyLoss()

# Function to evaluate model
def evaluate(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total


def train_and_evaluate(optimizer_fn, lr, weight_decay, num_epochs=5):
    """Trains and evaluates the CIFAR10CNN with a given optimizer and hyperparameters."""
    model = CIFAR10CNN().to(device)
    optimizer = optimizer_fn(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_accuracy = 0

    # Split training data into training and validation sets
    train_size = int(0.8 * len(train_ds))
    val_size = len(train_ds) - train_size
    train_dataset, val_dataset = random_split(train_ds, [train_size, val_size])

    train_loader_split = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)


    for epoch in range(1, num_epochs + 1):
        model.train()
        for i, (x, y) in enumerate(train_loader_split):
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        # Evaluate on the validation set
        val_acc = evaluate(model, val_loader)
        best_accuracy = max(best_accuracy, val_acc)

        scheduler.step()

    return best_accuracy

# Define the optimizers and their hyperparameter search spaces
optimizers_to_sweep = {
    "Muon": {
        "optimizer_fn": lambda params, lr, weight_decay: Muon(params, lr=lr, weight_decay=weight_decay),
        "lr_values": [1e-2, 5e-3, 1e-3, 5e-4],
        "weight_decay_values": [0, 1e-4, 1e-3]
    },
    "AdamW": {
        "optimizer_fn": lambda params, lr, weight_decay: torch.optim.AdamW(params, lr=lr, weight_decay=weight_decay),
        "lr_values": [1e-2, 5e-3, 1e-3, 5e-4],
        "weight_decay_values": [0, 1e-4, 1e-3]
    }
}

results = {}

# Perform the hyperparameter sweep for each optimizer
for opt_name, opt_info in optimizers_to_sweep.items():
    print(f"\n--- Hyperparameter sweep for {opt_name} ---")
    optimizer_fn = opt_info["optimizer_fn"]
    lr_values = opt_info["lr_values"]
    weight_decay_values = opt_info["weight_decay_values"]

    results[opt_name] = {}

    for lr in lr_values:
        for weight_decay in weight_decay_values:
            print(f"Training with lr={lr}, weight_decay={weight_decay}")
            accuracy = train_and_evaluate(optimizer_fn, lr, weight_decay)
            results[opt_name][(lr, weight_decay)] = accuracy
            print(f"Validation Accuracy: {accuracy:.2f}%")

# Print the results and best hyperparameters for each optimizer
print("\n--- Hyperparameter Sweep Results ---")
for opt_name, opt_results in results.items():
    print(f"\n{opt_name}:")
    for (lr, weight_decay), accuracy in opt_results.items():
        print(f"  (lr={lr}, weight_decay={weight_decay}): {accuracy:.2f}%")

    best_params = max(opt_results, key=opt_results.get)
    print(f"Best hyperparameters for {opt_name}: (lr={best_params[0]}, weight_decay={best_params[1]}) with validation accuracy {opt_results[best_params]:.2f}%")
# Out:
# --- Hyperparameter sweep for Muon ---
# Training with lr=0.01, weight_decay=0
# Validation Accuracy: 35.88%
# Training with lr=0.01, weight_decay=0.0001
# Validation Accuracy: 35.17%
# Training with lr=0.01, weight_decay=0.001
# Validation Accuracy: 36.71%
# Training with lr=0.005, weight_decay=0
# Validation Accuracy: 29.31%
# Training with lr=0.005, weight_decay=0.0001
# Validation Accuracy: 28.79%
# Training with lr=0.005, weight_decay=0.001
# Validation Accuracy: 28.28%
# Training with lr=0.001, weight_decay=0
# Validation Accuracy: 17.96%
# Training with lr=0.001, weight_decay=0.0001
# Validation Accuracy: 21.32%
# Training with lr=0.001, weight_decay=0.001
# Validation Accuracy: 18.86%
# Training with lr=0.0005, weight_decay=0
# Validation Accuracy: 14.79%
# Training with lr=0.0005, weight_decay=0.0001
# Validation Accuracy: 16.48%
# Training with lr=0.0005, weight_decay=0.001
# Validation Accuracy: 19.67%
#
# --- Hyperparameter sweep for AdamW ---
# Training with lr=0.01, weight_decay=0
# Validation Accuracy: 10.14%
# Training with lr=0.01, weight_decay=0.0001
# Validation Accuracy: 45.85%
# Training with lr=0.01, weight_decay=0.001
# Validation Accuracy: 37.68%
# Training with lr=0.005, weight_decay=0
# Validation Accuracy: 52.53%
# Training with lr=0.005, weight_decay=0.0001
# Validation Accuracy: 56.53%
# Training with lr=0.005, weight_decay=0.001
# Validation Accuracy: 56.61%
# Training with lr=0.001, weight_decay=0
# Validation Accuracy: 67.50%
# Training with lr=0.001, weight_decay=0.0001
# Validation Accuracy: 67.21%
# Training with lr=0.001, weight_decay=0.001
# Validation Accuracy: 66.37%
# Training with lr=0.0005, weight_decay=0
# Validation Accuracy: 62.60%
# Training with lr=0.0005, weight_decay=0.0001
# Validation Accuracy: 61.72%
# Training with lr=0.0005, weight_decay=0.001
# Validation Accuracy: 61.19%
#
# --- Hyperparameter Sweep Results ---
#
# Muon:
#   (lr=0.01, weight_decay=0): 35.88%
#   (lr=0.01, weight_decay=0.0001): 35.17%
#   (lr=0.01, weight_decay=0.001): 36.71%
#   (lr=0.005, weight_decay=0): 29.31%
#   (lr=0.005, weight_decay=0.0001): 28.79%
#   (lr=0.005, weight_decay=0.001): 28.28%
#   (lr=0.001, weight_decay=0): 17.96%
#   (lr=0.001, weight_decay=0.0001): 21.32%
#   (lr=0.001, weight_decay=0.001): 18.86%
#   (lr=0.0005, weight_decay=0): 14.79%
#   (lr=0.0005, weight_decay=0.0001): 16.48%
#   (lr=0.0005, weight_decay=0.001): 19.67%
# Best hyperparameters for Muon: (lr=0.01, weight_decay=0.001) with validation accuracy 36.71%
#
# AdamW:
#   (lr=0.01, weight_decay=0): 10.14%
#   (lr=0.01, weight_decay=0.0001): 45.85%
#   (lr=0.01, weight_decay=0.001): 37.68%
#   (lr=0.005, weight_decay=0): 52.53%
#   (lr=0.005, weight_decay=0.0001): 56.53%
#   (lr=0.005, weight_decay=0.001): 56.61%
#   (lr=0.001, weight_decay=0): 67.50%
#   (lr=0.001, weight_decay=0.0001): 67.21%
#   (lr=0.001, weight_decay=0.001): 66.37%
#   (lr=0.0005, weight_decay=0): 62.60%
#   (lr=0.0005, weight_decay=0.0001): 61.72%
#   (lr=0.0005, weight_decay=0.001): 61.19%
# Best hyperparameters for AdamW: (lr=0.001, weight_decay=0) with validation accuracy 67.50%

# %%
def train_and_evaluate_no_decay(optimizer_fn, lr, num_epochs=5):
    """Trains and evaluates the CIFAR10CNN with a given optimizer and hyperparameters."""
    model = CIFAR10CNN().to(device)
    optimizer = optimizer_fn(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_accuracy = 0

    # Split training data into training and validation sets
    train_size = int(0.8 * len(train_ds))
    val_size = len(train_ds) - train_size
    train_dataset, val_dataset = random_split(train_ds, [train_size, val_size])

    train_loader_split = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)


    for epoch in range(1, num_epochs + 1):
        model.train()
        for i, (x, y) in enumerate(train_loader_split):
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        # Evaluate on the validation set
        val_acc = evaluate(model, val_loader)
        best_accuracy = max(best_accuracy, val_acc)

        scheduler.step()

    return best_accuracy

optimizers_to_sweep = {
    "SOAP": {
        "optimizer_fn": lambda params, lr: SOAP(params, lr=lr),
        "lr_values": [1e-2, 5e-3, 1e-3, 5e-4]
    },
    "Lion": {
        "optimizer_fn": lambda params, lr: Lion(params, lr=lr),
        "lr_values": [1e-2, 5e-3, 1e-3, 5e-4]
    }
}

results = {}

# Perform the hyperparameter sweep for each optimizer
for opt_name, opt_info in optimizers_to_sweep.items():
    print(f"\n--- Hyperparameter sweep for {opt_name} ---")
    optimizer_fn = opt_info["optimizer_fn"]
    lr_values = opt_info["lr_values"]

    results[opt_name] = {}

    for lr in lr_values:
          print(f"Training with lr={lr}")
          accuracy = train_and_evaluate_no_decay(optimizer_fn, lr)
          results[opt_name][lr] = accuracy
          print(f"Validation Accuracy: {accuracy:.2f}%")
# Out:
# --- Hyperparameter sweep for SOAP ---
# Training with lr=0.01
# Validation Accuracy: 50.05%
# Training with lr=0.005
# Validation Accuracy: 45.14%
# Training with lr=0.001
# Validation Accuracy: 30.95%
# Training with lr=0.0005
# Validation Accuracy: 25.58%
#
# --- Hyperparameter sweep for Lion ---
# Training with lr=0.01
# Validation Accuracy: 10.60%
# Training with lr=0.005
# Validation Accuracy: 23.50%
# Training with lr=0.001
# Validation Accuracy: 68.60%
# Training with lr=0.0005
# Validation Accuracy: 68.61%
#
# --- Hyperparameter Sweep Results ---
#
# SOAP:
#   (lr=0.01): 50.05%
#   (lr=0.005): 45.14%
#   (lr=0.001): 30.95%
#   (lr=0.0005): 25.58%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4021379458.py in <cell line: 0>()
#      69
#      70     best_params = max(opt_results, key=opt_results.get)
# ---> 71     print(f"Best hyperparameters for {opt_name}: lr={best_params[0]} with validation accuracy {opt_results[best_params]:.2f}%")
#
# TypeError: 'float' object is not subscriptable

# %%
# Print the results and best hyperparameters for each optimizer
print("\n--- Hyperparameter Sweep Results ---")
for opt_name, opt_results in results.items():
    print(f"\n{opt_name}:")
    for lr, accuracy in opt_results.items():
        print(f"  (lr={lr}): {accuracy:.2f}%")

    best_params = max(opt_results, key=opt_results.get)
    print(f"Best hyperparameters for {opt_name}: lr={best_params} with validation accuracy {opt_results[best_params]:.2f}%")
# Out:
# --- Hyperparameter Sweep Results ---
#
# SOAP:
#   (lr=0.01): 50.05%
#   (lr=0.005): 45.14%
#   (lr=0.001): 30.95%
#   (lr=0.0005): 25.58%
# Best hyperparameters for SOAP: lr=0.01 with validation accuracy 50.05%
#
# Lion:
#   (lr=0.01): 10.60%
#   (lr=0.005): 23.50%
#   (lr=0.001): 68.60%
#   (lr=0.0005): 68.61%
# Best hyperparameters for Lion: lr=0.0005 with validation accuracy 68.61%

# %% [markdown]
# ### Question 7 (Optional)
#
# **What were the best choices for hyperparameters for Muon? What about for AdamW?**

# %% [markdown]
# ### Question 8
# Any intuition on the reasons that make Lion the best optimizer for this task?
